# %%
SELECT * from sharks_metadata.csv

# %%
#scalar 
SELECT COUNT(*) from sharks_locs.csv

# %%
SELECT * from sharks_locs.csv LIMIT 10

# %%
SELECT id, count(*) FROM sharks_locs.csv
GROUP BY id

# %%
SELECT m.name, count(*)
FROM sharks_metadata.csv m
JOIN sharks_locs.csv l
ON (m.id = l.id)
GROUP BY 1

# %% [markdown]
# Also demo that we can use a SQL cell to query and join together a Dataframe and csv file

# %%
SELECT m.name, count(*)
FROM mdf m
JOIN sharks_locs.csv l
ON (m.id = l.id)
GROUP BY 1

# %%
# and reminder that the output of SQL cells are a Pandas Dataframe
combined.shape
