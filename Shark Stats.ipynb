# %%
name = ""

# %%
import pandas
df = pandas.merge(pandas.read_csv('sharks_metadata.csv'), 
                  pandas.read_csv('sharks_locs.csv'), 
                  on='id')
df

# %%
import random
if not name:
    name = random.choice(df.name)
    
name

# %%
filtered = df[df.name == name]
filtered
