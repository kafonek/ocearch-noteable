# %%
import pandas
df = pandas.read_csv('sharks_metadata.csv')
df

# %%
-- Execute this cell to return the list of tables
-- and views within the default schema of this database
-- (Use \help to learn more options)

\list

# %%
-- Edit the table or view name below and execute this cell
-- to return the definition of the relation
-- (Use \help to learn more options)

\describe sharks.metadata
