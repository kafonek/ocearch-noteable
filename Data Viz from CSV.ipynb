# %%
import pandas

# metadata df
mdf = pandas.read_csv("sharks_metadata.csv")
mdf

# %%
# locs df
ldf = pandas.read_csv('sharks_locs.csv')
ldf

# %%
combined = pandas.merge(ldf, mdf, on='id', how='left')
combined

# %%
combined
