# %%
# !pip install papermill papermill-origami -q

# %%
import papermill

# %%
import papermill as pm

file_id = "eb601e7b-c1a8-4a01-aaef-a420261d61ae" # shark stats notebook

pm.execute_notebook(f'noteable://{file_id}', 
                    None,
                    engine_name='noteable')
