# %%
select * from sharks_locs.csv

# %%
select * from sharks_metadata.csv

# %%
CREATE schema if not exists sharks

# %%
CREATE table if not exists sharks.sharks (
    id int primary key,
    name text unique not null,
    gender text not null,
    weight int,
    length int,
    species text not null)

# %%
import pandas
